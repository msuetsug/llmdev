# %%
import urllib.request
import datetime

def save_url_content(url):
    # 引数として受け取ったURLからデータ取得
    response = urllib.request.urlopen(url)
    # UTF-8形式にデコード
    html = response.read().decode("utf-8")
    # 日時から保存するファイル名を作成
    file_name = f"{datetime.datetime.now().strftime("%Y%m%d_%H%M%S")}.txt"
    # データをファイルに保存
    with open(file_name, "w", encoding="utf-8") as file:
        # コンテンツの先頭500文字を書き込み
        file.write(html[:500])
    # ファイル名を戻り値として返す
    return file_name


url = input("URLを入力してください: ")
file_name = save_url_content(url)
print(f"Content saved in: {file_name}")
# Out:
# Content saved in: 20260217_183952.txt
